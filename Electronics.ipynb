# %%
import pandas as pd

# %%
electronics=pd.read_csv('/content/electronics.csv')
electronics
# Out:
#        item_id  user_id  rating   timestamp   model_attr  \
# 0            0        0     5.0  1999-06-13       Female
# 1            0        1     5.0  1999-06-14       Female
# 2            0        2     3.0  1999-06-17       Female
# 3            0        3     1.0  1999-07-01       Female
# 4            0        4     2.0  1999-07-06       Female
# ...        ...      ...     ...         ...          ...
# 81914        2    78154     5.0  2012-02-08  Female&Male
# 81915     1259    78155     1.0  2012-02-08         Male
# 81916     1780    78156     1.0  2012-02-08         Male
# 81917     1577    78157     4.0  2012-02-08         Male
# 81918     1650    78158     NaN         NaN          NaN
#
#                       category      brand    year user_attr  split
# 0       Portable Audio & Video        NaN  1999.0       NaN    0.0
# 1       Portable Audio & Video        NaN  1999.0       NaN    0.0
# 2       Portable Audio & Video        NaN  1999.0       NaN    0.0
# ...

# %%
electronics.duplicated().sum()
# Out:
# np.int64(0)

# %%
electronics.head(5)
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
#
#   brand    year user_attr  split
# 0   NaN  1999.0       NaN    0.0
# 1   NaN  1999.0       NaN    0.0
# 2   NaN  1999.0       NaN    0.0
# 3   NaN  1999.0       NaN    0.0
# 4   NaN  1999.0       NaN    0.0

# %%
electronics.tail(5)
# Out:
#        item_id  user_id  rating   timestamp   model_attr  \
# 81914        2    78154     5.0  2012-02-08  Female&Male
# 81915     1259    78155     1.0  2012-02-08         Male
# 81916     1780    78156     1.0  2012-02-08         Male
# 81917     1577    78157     4.0  2012-02-08         Male
# 81918     1650    78158     NaN         NaN          NaN
#
#                       category      brand    year user_attr  split
# 81914               Headphones        NaN  2000.0       NaN    0.0
# 81915   Portable Audio & Video    Philips  2010.0       NaN    0.0
# 81916  Computers & Accessories   Logitech  2011.0       NaN    0.0
# 81917       Television & Video  Panasonic  2011.0       NaN    0.0
# 81918                      NaN        NaN     NaN       NaN    NaN

# %%
electronics.sample(5)
# Out:
#        item_id  user_id  rating   timestamp model_attr  \
# 66002      302    63177     1.0  2011-07-31       Male
# 9310       394     9009     1.0  2007-03-05     Female
# 42990      828    41325     5.0  2010-05-06       Male
# 30404      301    29375     5.0  2009-07-10       Male
# 20019      710    19422     5.0  2008-07-30     Female
#
#                       category    brand    year user_attr  split
# 66002    Car Electronics & GPS   Garmin  2006.0       NaN    0.0
# 9310   Computers & Accessories      NaN  2007.0       NaN    0.0
# 42990  Computers & Accessories      NaN  2008.0       NaN    0.0
# 30404    Car Electronics & GPS   Garmin  2007.0    Female    0.0
# 20019  Computers & Accessories  Linksys  2008.0       NaN    0.0

# %%
electronics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81919 entries, 0 to 81918
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_id     81919 non-null  int64
#  1   user_id     81919 non-null  int64
#  2   rating      81918 non-null  float64
#  3   timestamp   81918 non-null  object
#  4   model_attr  81918 non-null  object
#  5   category    81918 non-null  object
#  6   brand       41468 non-null  object
#  7   year        81918 non-null  float64
#  8   user_attr   7930 non-null   object
#  9   split       81918 non-null  float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 6.3+ MB

# %%
electronics.describe()
# Out:
#             item_id       user_id        rating          year         split
# count  81919.000000  81919.000000  81918.000000  81918.000000  81918.000000
# mean     811.547614  38519.556782      3.901951   2008.028382      0.055531
# std      502.101071  22588.273993      1.402444      2.630755      0.316087
# min        0.000000      0.000000      1.000000   1999.000000      0.000000
# 25%      366.000000  18908.000000      3.000000   2007.000000      0.000000
# 50%      752.000000  38223.000000      4.000000   2008.000000      0.000000
# 75%     1162.000000  58034.500000      5.000000   2010.000000      0.000000
# max     2056.000000  78158.000000      5.000000   2018.000000      2.000000

# %%
electronics.nunique()
# Out:
# item_id        2057
# user_id       78159
# rating            5
# timestamp      3930
# model_attr        3
# category         10
# brand            38
# year             20
# user_attr         2
# split             3
# dtype: int64

# %%
electronics.shape
# Out:
# (81919, 10)

# %%
electronics.isnull().sum()
# Out:
# item_id           0
# user_id           0
# rating            1
# timestamp         1
# model_attr        1
# category          1
# brand         40451
# year              1
# user_attr     73989
# split             1
# dtype: int64

# %%
electronics['brand'].unique()
# Out:
# array([nan, 'HP', 'Philips', 'Polaroid', 'Panasonic', 'JVC', 'Fujifilm',
#        'Nikon', 'Kodak', 'Sony', 'Canon', 'Kensington', 'Pyle', 'Olympus',
#        'Toshiba', 'Logitech', 'Etre Jeune', 'Linksys', 'Vivitar',
#        'Sennheiser', 'Apple', 'Samsung', 'EldHus', 'Bose', 'Archos',
#        'Garmin', 'Jabra', 'Gary Fong', 'ViewSonic', 'Savage', 'Uniden',
#        'ebasy', 'Generic', 'JLAB', 'Skullcandy', 'TaoTronics', 'Neewer',
#        'Koolertron', 'DURAGADGET'], dtype=object)

# %%
electronics['brand'].nunique()
# Out:
# 38

# %%
filter=electronics[electronics['brand']=='Kodak']
filter
# Out:
#        item_id  user_id  rating   timestamp   model_attr        category  \
# 182         14      182     5.0  2000-10-25  Female&Male  Camera & Photo
# 183         14      158     4.0  2000-10-28  Female&Male  Camera & Photo
# 189         15      188     5.0  2000-11-09  Female&Male  Camera & Photo
# 190         15      189     5.0  2000-11-10  Female&Male  Camera & Photo
# 197         15      196     5.0  2000-11-22  Female&Male  Camera & Photo
# ...        ...      ...     ...         ...          ...             ...
# 81689     1965    77946     5.0  2012-02-06       Female  Camera & Photo
# 81738     1438    77992     1.0  2012-02-06       Female  Camera & Photo
# 81784     1690    78034     4.0  2012-02-07       Female  Camera & Photo
# 81854     1945    78097     5.0  2012-02-08       Female  Camera & Photo
# 81880     1423    78123     5.0  2012-02-08       Female  Camera & Photo
#
#        brand    year user_attr  split
# 182    Kodak  2001.0       NaN    0.0
# ...

# %%
electronics.isnull()
# Out:
#        item_id  user_id  rating  timestamp  model_attr  category  brand  \
# 0        False    False   False      False       False     False   True
# 1        False    False   False      False       False     False   True
# 2        False    False   False      False       False     False   True
# 3        False    False   False      False       False     False   True
# 4        False    False   False      False       False     False   True
# ...        ...      ...     ...        ...         ...       ...    ...
# 81914    False    False   False      False       False     False   True
# 81915    False    False   False      False       False     False  False
# 81916    False    False   False      False       False     False  False
# 81917    False    False   False      False       False     False  False
# 81918    False    False    True       True        True      True   True
#
#         year  user_attr  split
# 0      False       True  False
# 1      False       True  False
# ...

# %%
electronics.isnull().sum()
# Out:
# item_id           0
# user_id           0
# rating            1
# timestamp         1
# model_attr        1
# category          1
# brand         40451
# year              1
# user_attr     73989
# split             1
# dtype: int64

# %%
electronics['split']=electronics['split'].fillna(0)

# %%
electronics['brand']=electronics['brand'].fillna('Unknown')

# %%
electronics['category']=electronics['category'].fillna('None')

# %%
electronics['category']=electronics['category'].fillna('Unknown')

# %%
electronics['user_attr']=electronics['user_attr'].fillna('Unknown')

# %%
electronics.isnull().sum()
# Out:
# item_id       0
# user_id       0
# rating        1
# timestamp     1
# model_attr    1
# category      0
# brand         0
# year          1
# user_attr     0
# split         0
# dtype: int64

# %%
grouped=electronics.groupby('model_attr')['rating'].sum()
grouped
# Out:
# model_attr
# Female         136766.0
# Female&Male     74810.0
# Male           108064.0
# Name: rating, dtype: float64

# %%
electronics.sort_values('rating',ascending=True)
# Out:
#        item_id  user_id  rating   timestamp   model_attr  \
# 81849     1750     1140     1.0  2012-02-07         Male
# 81860     1476    78103     1.0  2012-02-08  Female&Male
# 81830     1698    78077     1.0  2012-02-07         Male
# 81833     1128    78080     1.0  2012-02-07       Female
# 41487      679    39892     1.0  2010-03-27       Female
# ...        ...      ...     ...         ...          ...
# 1            0        1     5.0  1999-06-14       Female
# 81905     1543    78145     5.0  2012-02-08       Female
# 0            0        0     5.0  1999-06-13       Female
# 81907     1555    78147     5.0  2012-02-08         Male
# 81918     1650    78158     NaN         NaN          NaN
#
#                       category    brand    year user_attr  split
# 81849   Accessories & Supplies    Jabra  2011.0      Male    1.0
# 81860           Camera & Photo  Vivitar  2013.0   Unknown    0.0
# 81830           Camera & Photo  Unknown  2012.0   Unknown    0.0
# ...

# %%
filter=electronics[electronics['category']=='Camera & Photo']
filter
# Out:
#        item_id  user_id  rating   timestamp model_attr        category  \
# 78           3       78     4.0  2000-03-28     Female  Camera & Photo
# 79           3       79     5.0  2000-03-28     Female  Camera & Photo
# 80           3       80     4.0  2000-03-30     Female  Camera & Photo
# 81           3       81     5.0  2000-03-31     Female  Camera & Photo
# 84           3       84     1.0  2000-04-06     Female  Camera & Photo
# ...        ...      ...     ...         ...        ...             ...
# 81880     1423    78123     5.0  2012-02-08     Female  Camera & Photo
# 81900     1564    78140     5.0  2012-02-08     Female  Camera & Photo
# 81904       41    78144     5.0  2012-02-08     Female  Camera & Photo
# 81907     1555    78147     5.0  2012-02-08       Male  Camera & Photo
# 81908     1605    78148     4.0  2012-02-08     Female  Camera & Photo
#
#          brand    year user_attr  split
# 78     Unknown  2005.0   Unknown    0.0
# ...

# %%
electronics['split'].unique()
# Out:
# array([0., 2., 1.])

# %%
electronics['category'].unique()
# Out:
# array(['Portable Audio & Video', 'Computers & Accessories', 'Headphones',
#        'Camera & Photo', 'Television & Video', 'Home Audio',
#        'Accessories & Supplies', 'Car Electronics & GPS',
#        'Security & Surveillance', 'Wearable Technology', 'None'],
#       dtype=object)

# %%
electronics['category'].nunique()
# Out:
# 11

# %%
electronics['year'].unique()
# Out:
# array([1999., 2000., 2005., 2015., 2001., 2018., 2006., 2003., 2007.,
#        2017., 2002., 2004., 2011., 2013., 2014., 2012., 2009., 2016.,
#        2008., 2010.,   nan])

# %%
electronics['year'].nunique()
# Out:
# 20

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x='year',y='rating',data=electronics)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
electronics.head()
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
#
#      brand    year user_attr  split
# 0  Unknown  1999.0   Unknown    0.0
# 1  Unknown  1999.0   Unknown    0.0
# 2  Unknown  1999.0   Unknown    0.0
# 3  Unknown  1999.0   Unknown    0.0
# 4  Unknown  1999.0   Unknown    0.0

# %%
electronics['timestamp'] = pd.to_datetime(electronics['timestamp'])
electronics['Year']=electronics['timestamp'].dt.year
electronics['Month']=electronics['timestamp'].dt.month
electronics['Day']=electronics['timestamp'].dt.day
electronics
# Out:
#        item_id  user_id  rating  timestamp   model_attr  \
# 0            0        0     5.0 1999-06-13       Female
# 1            0        1     5.0 1999-06-14       Female
# 2            0        2     3.0 1999-06-17       Female
# 3            0        3     1.0 1999-07-01       Female
# 4            0        4     2.0 1999-07-06       Female
# ...        ...      ...     ...        ...          ...
# 81914        2    78154     5.0 2012-02-08  Female&Male
# 81915     1259    78155     1.0 2012-02-08         Male
# 81916     1780    78156     1.0 2012-02-08         Male
# 81917     1577    78157     4.0 2012-02-08         Male
# 81918     1650    78158     NaN        NaT          NaN
#
#                       category      brand    year user_attr  split    Year  \
# 0       Portable Audio & Video    Unknown  1999.0   Unknown    0.0  1999.0
# 1       Portable Audio & Video    Unknown  1999.0   Unknown    0.0  1999.0
# ...

# %%
plt.pie(electronics['model_attr'].value_counts(),labels=electronics['model_attr'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %%
sns.lineplot(x='Day',y='rating',data=electronics)
plt.show()

# %%
sns.lineplot(x='Month',y='rating',data=electronics)
plt.show()

# %%
sns.lineplot(x='Year',y='rating',data=electronics)
plt.show()

# %%
sns.barplot(x='brand',y='rating',data=electronics)
electronics.sort_values(by='brand',ascending=True)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
sns.barplot(x='category',y='rating',data=electronics)
electronics.sort_values(by='brand',ascending=True)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
